# %% [raw]
# print("hello")

# %%
# Initialize variables
num1 = 5
num2 = 10

# Add numbers and store in result
result = num1 + num2

# Display output
print(f"The sum of {num1} and {num2} is: {result}")
# Out:
# The sum of 5 and 10 is: 15

# %%
print(5)
# Out:
# 5

# %%
print("hello world", 5)
# Out:
# hello world 5

# %%
print("hello", 7)
print(5)
print("bye")

# %%
print(17+17)
print(5-5)
print(6*6)
print(49/7)

# %%
print("Hey this is a dog\nand this is a cat")

# %%
print("test")

# %%
# My name is not Harry
print("My name is Harry")

# %%
"""
I am trying multi line comments
Author: Hanan
DOB: 2003
"""
print("Trying multi line comments")

# %%
# print("This is an "escape")
      print("This is \"an escape")

# %%
print("This is an "escape")

# %%
print("This is \" an escape")

# %%
print ("hey this is a \"dog\"\nand this is a cat")

# %%
print("Hey I am\' a \"good boy\"\nand this viewer is also a good boy/girl")
print("Hey", 6, 7, sep="~", end="009\n")
print("Harry")

# %%
a = 1416
print(a)
b ="Harry"
print(b)

# %%
a =  5
print(a)
a1 = 10
b="Harry"
print(b)
print(a+a1)
print("The type of a variable is", type(a))
print("The type of b variable is", type(b))
print("The type of a1 variable is", type(a1))

# %%
a = 1
b =  True
c = "Harry"
d =  None
a1 = 2
print(a)
print(b)
print(c)
print(d)
print(a1)
print(a+a1)
print("The type of variable a is", type(a))
print("The type of variable b is", type(b))
print("The type of variable c is", type(c))
print("The type of variable d is", type(d))
print("The type of variable a1 is", type(a1))

# %%
print(2+2) #addition
print(2-2) #subtraction
print(2*2) #multiplication
print(15/6) #divison
print(15//6) #floor division
print(2%3) #modulus
print(2**3) #exponential

# %%
input()

# %%
a= 50
b= 3
print("The value of", a,"+",b, "is equal to:", a+b)
print("The value of", a,"-",b, "is equal to:", a-b)
print("The value of", a,"*",b, "is equal to:", a*b)
print("The value of", a,"/",b, "is equal to:", a/b)

# %%
#You have 500 rupees. A burger costs 120, fries cost 60, a drink costs 45. Calculate the total bill and how much change you get
a = 500
b = 120
f = 60
d = 45
print("Total bill is", b+f+d)
print("Totl change we get is", a-b-f-d)
#A rectangle has length 15 and width 8. Calculate its area and perimeter
l = 15
b = 8
print("Total area of reactangle is equal to:",l*b)
print("Total perimeter of reactangle is equal to:",2*(l+b))
#You scored 78 out of 120 in an exam. Calculate your percentage
m = 78
t = 120
print("Percentage of marks is equal to:",m/t*100)
# A car travels 240 km on 8 litres of fuel. Calculate fuel efficiency (km per litre)
r = 240
p = 8
print("Total fuel efficiency i.e. milage of car is equal to:",r/p)
# Calculate the simple interest: principal=5000, rate=8, time=3.
principal = 5000
rate = 8
time = 3
print("Simple interest is equal to:", principal*rate*time/100)
# Create a variable greeting = "Hello" and a variable name = "Hanan", join them together and print
greeting = "Hello"
name = "Hanan"
print(greeting + name)

# %%
# You buy 3 kg of apples at 80 rupees per kg, 2 kg of bananas at 40 rupees per kg. Calculate total cost
a = 80
b = 40
print("Total cost of 3 kg apple and 2 kg bananas at the rate of 80 and 40 rupees per kg is:", 3*a + 2*b)

# %%
# A shopkeeper gives 15% discount on a 2000 rupee item. Calculate the discount amount and final price
p = 2000
print("The discount amount on 2000 rupees given by shopkeeper is:", 2000*15/100)
print("The final price after the discount is:", 2000-(2000*15/100))

# %%
# You and 4 friends go to a restaurant. Total bill is 1850 rupees. Calculate each person's share
c = 1850
print("Each person's share is equal to:", 1850/5)

# %%
 # Calculate the area and circumference of a circle with radius 7.
r = 7
print("The area of circle is:", 3.14159*7**2)
print("The circumference of circle is :", 2*3.14159*7)

# %%
 # Calculate the volume of a box with length 10, width 6, height 4
l = 10
w = 6
h = 4
print("The volume of box is equal to:", l*w*h)

# %%
 # Convert 100 US dollars to Pakistani rupees (1 USD = 278 PKR)
USD = 100
Rate = 278
print("100 US dollars are equal to:", USD*Rate,"Pakistani rupees")

# %%
# Convert 5 feet 9 inches to centimeters (1 inch = 2.54 cm)
c = 1
i = 2.54
f = 12
print("9 inches are equal to:",9*2.54,"centimeters")
x = 9*2.54
print("5 feet are  equal to:",(5*12)*2.54,"centimeters")
y = (5*12)*2.54
print("Therefore 5 feet 9 inches are equal to:",x+y)

# %%
# A student scored 85, 90, 78, 92, 88 in 5 subjects. Calculate total marks and average.
a = 85
b = 90
c = 78
d = 92
e = 88
print("Total marks are equal to:",a+b+c+d+e)
print("Average marks are equal to:",(a+b+c+d+e)/5)

# %%
 # A train travels at 90 km/h. How long will it take to cover 450 km?
s = 90
d = 450
print("Train will take:",d/s,"hours to cover 450km")

# %%
 # A shop buys an item for 800 rupees and sells it for 1100 rupees. Calculate the profit and profit percentage. 
i = 800
s = 1100
print("Profit is equal to:",s-i)
x = s-i
print("Profit percentage is equal to:",(x/i)*100)

# %%
a = "1"
b = "2"
print(a+b)

# %%
a = "1"
b = "2"
print(int(a) + int(b))

# %%
 = 3
float = 3.9
print(int+float)
print("int is of the type:",type(int))
print("float is of the type:",type(float))

# %%
input()

# %%
a = input()
print("My name is:",a)

# %%
a = input("Enter your name:")
print("My name is:",a)

# %%
# Taking two values from user and adding them
x = input("Enter first number:")
y = input("Enter second number:")
print(x+y)

# %%
num1 = input("Enter first number:")
num2 = input("Enter second number:")
print("Output is equal to:",int(num1)+int(num2))

# %%
x1 = input("Enter you name:")
print("Your name is:",x1)
x2 = input("Enter first number:")
x3 = input("Enter second number:")
print(x2+x3)
print(int(x2)+int(x3))

# %%
m1 = input("Enter first number:")
m2 = input("Enter second number:")
print(m1+m2)
print(m1-m2)
print(m1*m2)
print(m1/m2)
print(m1**m2)'
print(m1//m2)
print(m1%m2)

# %%
m1 = int(input("Enter first number:"))
m2 = int(input("Enter second number:"))
print(m1+m2)
print(m1-m2)
print(m1*m2)
print(m1/m2)
print(m1**m2)
print(m1//m2)
print(m1%m2)

# %%
car1 = "Hanan"
car2 = "John"
car3 = "David"
print("Hello",car1,car2,"and",car3)

# %%
cmnt = "He said, \"I want to eat an apple\""
print(cmnt)

# %%
# using multiline comments using 3 methods
name = """My name is Hanan
I am a student 
I study at IUST"""
print(name)
name1 = '''My name is David
I am a student 
I study at IUST'''
print(name1)
name2 = "My name is John\nI am a student\nI study at IUST"
print(name2)

# %%
name = "Hanan"
print("Hello,",name)
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[5])

# %%
names = "Hanan,David"
print(names[0:5])
print(len(names))

# %%
fruit = "pineapple"
print("pineapple is a",len(fruit),"lettered word")

# %%
# Slicing in 3 different ways
fruits = "Apple, Banana, Orange"
print(fruits[0:5])
print(fruits[:5])
print(fruits[:])

# %%
animal = "elephant"
print(animal[0:-3])

# %%
myname = "hanan"
lengthname = len(myname)
print(lengthname)
print(name[-3:-1])

# %%
nm = "harry"
print(nm[-4:-2])

# %%
x = float("7")
print(x)

# %%
num = input("Enter a number: ")
print(num + 10)

# %%
nmb = "10"
print(nmb+"10")

# %%
# Write one line of code that takes a number from the user and stores it as a float.
Numeral = input("Enter a number:")
print(float(Numeral))

# %%
x = "Artificial Intelligence"
print(len(x))

# %%
# Write code to store a multiline string with 3 lines in one variable.
variable = """I am a human
This is a car
This is a dog"""
print(variable)

# %%
x = "Machine"
print(x[0:3])

# %%
x = "Learning"
print(x[::2])

# %%
x = "elephants"
print(x[::2])

# %%
x = "Kashmir"
print(x[-3:])

# %%
x = "12.5"
y = float(x)
print(y * 2)

# %%
name = "Hanan"
print(name[10])

# %%
x = "AI Engineer"
print(x[3:7])

# %%
x = "Artificial"
print(x[::2])    # every 2nd character
print(x[::-1])   # reversed
print(x[::3])    # every 3rd character
print(x[::-2])   # reversed, every 2nd

# %%
# Take a word from the user and print it reversed using slicing
word = input("Enter a word:")
print(word[::-1])

# %%
# Take a sentence from the user and print every 2nd character
sen = input("Enter a sentence:")
print(sen[::2])

# %%
# Store this string and print only "Intelligence":
# x = "Artificial Intelligence"
i = "Artificial Intelligence"
print(i[11:])

# %%
# Take the user's full name as input, print how many characters it has (including space)
username = input("Enter your full name:")
print(len(username))

# %%
# Store this multiline string and print only the 2nd line:
# x = """Kashmir
# is
# beautiful"""
strg = """Kashmir
is
beautiful"""
print(strg[8:10])

# %%
 # Take a number from the u:"ser as input, convert it to int and float both, print both results
num = input("Enter a number:")
print(int(float(num)))
print(float(num))

# %%
# Store "Engineering" in a variable, print every 3rd character using step slicing
vb = "Engineering"
print(vb[::3])

# %%
# Take two numbers from the user, convert them to float, print their average
n1 = float(input("Enter first number:"))
n2 = float(input("Enter second number:"))
print((n1+n2)/2)

# %%
 # Store your full name in a variable, print the last 3 characters using negative slicing
mynm = "Hanan Rawa"
print(mynm[-3:])

# %%
# Take a word from the user, print:
# First 3 characters
# Last 3 characters
# The word reversed
giv = input("Enter a word:")
print(giv[:-2])
print(giv[-3:])
print(giv[::-1])

# %%
n3 = "Tiger"
print(n3[-4:-2])

# %%
j = "Hanan"
print(j.upper())
# Out:
# HANAN

# %%
k = "Hanan"
print(k.lower())
# Out:
# hanan

# %%
q = "Hanan!!!!!!!!!!!!!"
print(q.upper())
print(q.lower())
print(q.rstrip("!"))
# Out:
# HANAN!!!!!!!!!!!!!
# hanan!!!!!!!!!!!!!
# Hanan

# %%
m1 = "hanan"
print(m1.replace("hanan", "david"))
# Out:
# david

# %%
m2 = "hanan!! !! David"
print(m2.split(" "))
# Out:
# ['hanan!!', '!!', 'David']

# %%
m3 = "Introduction to Artificial Intelligence"
print(m3.capitalize())
# Out:
# Introduction to artificial intelligence

# %%
m5 = "Welcome to the Console!!!"
print(len(m5))
print(m5.center(50))
print(len(m5.center(50)))
# Out:
# 25
#             Welcome to the Console!!!
# 50

# %%
m4 = "Hanan!! Hanan!!"
print(m4.count("!"))
print(m4.count("Hanan"))
# Out:
# 4
# 2

# %%
m6 = "Hanan!!!"
print(m6.endswith("!!!"))
# Out:
# True

# %%
m7 =  "My name is Hanan"
print(m7.endswith("ame",4,7))
# Out:
# True

# %%
m8 = "My name"
print(m8.find("na"))
print(m8.find("nam"))
print(m8.find("n"))
print(m8.find("mz"))
print(m8.find("z"))
# Out:
# 3
# 3
# 3
# -1
# -1

# %%
k1 = "He's name is Dan. He is an honest man"
print(k1.find("is"))
# Out:
# 10

# %%
k2 = "He's name is Dan. He is an honest man"
print(k2.index("is"))
# Out:
# 10

# %%
k2 = "He's name is Dan. He is an honest man"
print(k2.index("iss"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 2
#       1 k2 = "He's name is Dan. He is an honest man"
# ----> 2 print(k2.index("iss"))
#
# ValueError: substring not found

# %%
k3 = "Mynameisnotfound3"
print(k3.isalnum())
# Out:
# True

# %%
k4 = "Myname"
print(k4.isalpha())
# Out:
# True

# %%
k5 = "Myname00"
print(k5.isalpha())
# Out:
# False

# %%
k6 = "hanan"
print(k6.islower())
# Out:
# True

# %%
h1 = "My dog\nis of German origin"
h2 = "My dog is of German origin"
print(h1)
print(h2)
print(h1.isprintable())
print(h2.isprintable())
# Out:
# My dog
# is of German origin
# My dog is of German origin
# False
# True

# %%
h3 = "         "
print(h3.isspace())
h4 = ""
print(h4.isspace())
# Out:
# True
# False

# %%
h5 = "Hanan"
h6 = "hanan"
h7 = "Hanan is a Human"
print(h5.istitle())
print(h6.istitle())
print(h7.istitle())
# Out:
# True
# False
# False

# %%
l1 = "hanan Is"
l2 = "hanan is"
print(l1.islower())
print(l2.islower())
# Out:
# False
# True

# %%
p1 = "python is an object oriented language"
print(p1.startswith("py"))
print(p1.startswith("ob",13,15))
# Out:
# True
# True

# %%
p2 = "HaNaN"
print(p2.swapcase())
# Out:
# hAnAn

# %%
p3 = "hanan"
print(p3.swapcase())
# Out:
# HANAN

# %%
z1 = "My name is hanan"
print(z1.title())
# Out:
# My Name Is Hanan

# %%
# Take a sentence from user, print it in uppercase and lowercase
s = input("Enter a sentence:")
print(s.upper())
print(s.lower())
# Out:
# Enter a sentence: My name is Hanan
# MY NAME IS HANAN
# my name is hanan

# %%
# Store "  Hello World  ", strip the spaces and print it
l = " Hello World "
print(l.strip())
# Out:
# Hello World

# %%
# Store "Python is great", replace "great" with "awesome" and print
s = "Python is great"
print(s.replace("great","awesome"))
# Out:
# Python is awesome

# %%
# Store "apple,banana,mango,grape", split it and print the result
l1 = "apple,banana,mango,grape"
print(l1.split(","))
# Out:
# ['apple', 'banana', 'mango', 'grape']

# %%
# Store "hanan rawa", print it in title case
n = "hanan rawa"
print(n.title())
# Out:
# Hanan Rawa

# %%
# Store "Hello World", print it center aligned with 30 spaces
k = "Hello World"
print(k.center(30))
# Out:
#          Hello World

# %%
# Store "Mississippi", count how many times "s" appears
u = "Mississippi"
print(u.count("s"))
# Out:
# 4

# %%
# Store "Artificial Intelligence", find the index of "I"
m = "Artificial Intelligence"
print(m.index("i"))
